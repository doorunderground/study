# %%
import cv2
import matplotlib.pyplot as plt

#-- openCV가 제공하는 얼굴 검출 모델
#-- xml 파일에 들어 있는 얼굴 판별 규칙을 메모리에 로드해라.
face_cascade = cv2.CascadeClassifier(
    r"C:\\study\\deeplearning\\haarcascade_frontalface_default.xml"
)

#-- 전터리
bgr = cv2.imread(r"C:\\study\\deeplearning\\1234.jpg")

#-- 컬러 이미지(BGR) -> 흑백(Grayscale)로 변환
#-- haarcascade는 색 정보를 사용하지 않음
#-- 3채널 -> 1채널
#-- 밝기 패턴만 분석해서 -> 연산속도 up, 노이즈 down
gray = cv2.cvtColor(bgr, cv2.COLOR_BGR2GRAY)
gray = cv2.equalizeHist(gray)

#-- face detect
faces = face_cascade.detectMultiScale(gray)

#print("detected faces:", len(faces))

dst = bgr.copy()
for (x, y, w, h) in faces:
    cv2.rectangle(dst, (x, y), (x+w, y+h), (0, 0, 255), 3)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
